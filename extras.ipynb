# %%
# !pip install sentence_transformers
# Out:
# ...
#    ---------------------------------------- 0.0/588.9 kB ? eta -:--:--
#    ---------------------------------------- 588.9/588.9 kB 7.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    ------------------- -------------------- 5.5/11.2 MB 27.9 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.2 MB 23.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 19.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/693.4 kB ? eta -:--:--
#    ---------------------------------------- 693.4/693.4 kB 13.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------------------------------------ --- 3.7/4.0 MB 18.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 16.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    -------------------------------------- - 2.6/2.7 MB 21.4 MB/s eta 0:00:01
# ...

# %%
# !pip install vaderSentiment
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\pragy\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (c:\Users\pragy\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\pragy\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (c:\Users\pragy\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\pragy\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (c:\Users\pragy\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install peft
# Out:
# ...
#    ---------------------------------------- 0.0/680.7 kB ? eta -:--:--
#    ---------------------------------------- 680.7/680.7 kB 6.6 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [accelerate]
#    ---------------------------------------- 0/2 [accelerate]
#    ---------------------------------------- 0/2 [accelerate]
#    ---------------------------------------- 0/2 [accelerate]
#    ---------------------------------------- 0/2 [accelerate]
#    ---------------------------------------- 0/2 [accelerate]
#    ---------------------------------------- 0/2 [accelerate]
#    ---------------------------------------- 0/2 [accelerate]
#    ---------------------------------------- 0/2 [accelerate]
#    ---------------------------------------- 0/2 [accelerate]
#    ---------------------------------------- 0/2 [accelerate]
#    ---------------------------------------- 0/2 [accelerate]
#    -------------------- ------------------- 1/2 [peft]
# ...

# %%
# !pip install tiktoken
# Out:
# ...
#    ---------------------------------------- 0.0/876.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/876.5 kB ? eta -:--:--
#    ---------------------------------------- 876.5/876.5 kB 2.6 MB/s  0:00:00
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\pragy\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (c:\Users\pragy\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\pragy\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (c:\Users\pragy\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\pragy\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (c:\Users\pragy\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#
# ...
